# %%
wordsDF = sqlContext.createDataFrame([("emr",), ("spark",), ("example",), ("spark",), ("pyspark",), ("python",),
             ("example",), ("emr",), ("example",), ("spark",), ("pyspark",), ("python",)], ["words"])
wordsDF.show()
wordsDF.printSchema()
# Out:
# VBox()
# Starting Spark application
# <table>
# <tbody><tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>1</td><td>application_1729133052319_0002</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-10-2-64-24.ap-southeast-3.compute.internal:20888/proxy/application_1729133052319_0002/" class="emr-proxy-link j-9M5F2KY4568U application_1729133052319_0002" emr-resource="j-9M5F2KY4568U
# " application-id="application_1729133052319_0002">Link</a></td><td><a target="_blank" href="http://ip-10-2-64-23.ap-southeast-3.compute.internal:8042/node/containerlogs/container_1729133052319_0002_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></tbody></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+
# |  words|
# +-------+
# |    emr|
# |  spark|
# |example|
# |  spark|
# |pyspark|
# | python|
# |example|
# |    emr|
# |example|
# |  spark|
# |pyspark|
# | python|
# +-------+
#
# root
#  |-- words: string (nullable = true)

# %%
wordsCounts.saveAsTextFile("s3://EXAMPLE-BUCKET/word-count") # Change this to the S3 location that you created in Setup step 1.
