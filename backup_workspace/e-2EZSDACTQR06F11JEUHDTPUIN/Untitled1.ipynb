# %%
# Read the CSV file into a DataFrame
df = spark.read.csv("hdfs:///user/hadoop/employee_data.csv", header=True, inferSchema=True)

# Show the DataFrame
df.show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---+---------+--------+---+-------+----------+----------+-----------+
# | id|firstname|lastname|age|dept_id| born_city| born_date|age_of_work|
# +---+---------+--------+---+-------+----------+----------+-----------+
# |  1|   QYbRxF|VhbPMuht| 36|     77|ygptEXwtrs|1995-02-27|         14|
# |  2|   SwGuje|kuQCDeRf| 20|     57|BUTrlMAtjU|1957-06-04|         -2|
# |  3|   MbhtKY|sjenQtVC| 22|     80|zQXDInOuri|1986-07-07|          2|
# |  4|   ZXEdyb|TNdmDYDI| 58|     46|VCKZgIgsll|1991-04-19|         38|
# |  5|   zZtNtN|qxrRbgPG| 20|     10|eBErCSgovD|1947-05-10|          0|
# |  6|   OnFcSH|noLtocgh| 50|     41|ztxvltYhqE|1999-03-25|         31|
# |  7|   VemBgv|AhgPxEyU| 38|     56|IMfvYiUTMi|1941-02-18|         18|
# |  8|   DrzKTe|MPjXDzKz| 45|     76|xjOVHjAIsu|1980-12-26|         26|
# |  9|   qdPwaF|ENwDCvCl| 42|    100|aNDVYUHzHJ|1940-05-21|         24|
# | 10|   oUbaEP|kXPTouql| 42|     31|uLSFRyuCMy|1995-10-27|         23|
# | 11|   arnQVA|AzeIrwBp| 46|     51|MwYfqmzrwn|1976-03-12|         26|
# | 12|   yXSSgP|TVfrtaCH| 44|     14|cttxZrsTfv|1995-03-02|         26|
# | 13|   lUzMTg|ILlqGhTI| 32|      7|QwgUTzvgtM|1988-05-18|         12|
# | 14|   fgjjFq|sjQfEdYO| 47|     93|GzNMlAgrpK|1950-07-08|         25|
# | 15|   VhtUaq|uKFTRVRg| 33|      9|SuWXVEgOvc|1941-04-11|         11|
# | 16|   NPKUPH|vOtqdJlW| 22|     76|kyiXJkoEJm|1952-06-21|          2|
# | 17|   SvVCba|hvBrSroi| 46|     61|ImUcAHMJXw|1951-01-11|         27|
# | 18|   vSzmvz|aOTmfMPM| 52|     38|zLfJQbDdfe|1941-02-20|         34|
# | 19|   QfHIoN|TBFFQPbM| 19|      9|wKiFMATUNh|1974-07-05|          0|
# | 20|   cbJuGK|iUtUaLax| 47|     57|bJNIXMICci|1968-09-21|         25|
# +---+---------+--------+---+-------+----------+----------+-----------+
# only showing top 20 rows

# %%
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# An error was encountered:
# name 'rdd' is not defined
# Traceback (most recent call last):
# NameError: name 'rdd' is not defined

# %%
Data.take(5)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ['id,firstname,lastname,age,dept_id,born_city,born_date,age_of_work', '1,QYbRxF,VhbPMuht,36,77,ygptEXwtrs,1995-02-27,14', '2,SwGuje,kuQCDeRf,20,57,BUTrlMAtjU,1957-06-04,-2', '3,MbhtKY,sjenQtVC,22,80,zQXDInOuri,1986-07-07,2', '4,ZXEdyb,TNdmDYDI,58,46,VCKZgIgsll,1991-04-19,38']

# %%
# Out:
# VBox()
# Starting Spark application
# <table>
# <tbody><tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>21</td><td>application_1729133052319_0026</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-10-2-64-24.ap-southeast-3.compute.internal:20888/proxy/application_1729133052319_0026/" class="emr-proxy-link j-9M5F2KY4568U application_1729133052319_0026" emr-resource="j-9M5F2KY4568U
# " application-id="application_1729133052319_0026">Link</a></td><td><a target="_blank" href="http://ip-10-2-64-30.ap-southeast-3.compute.internal:8042/node/containerlogs/container_1729133052319_0026_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></tbody></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# An error was encountered:
# list index out of range
# Traceback (most recent call last):
#   File "/mnt2/yarn/usercache/livy/appcache/application_1729133052319_0026/container_1729133052319_0026_01_000001/pyspark.zip/pyspark/sql/session.py", line 1443, in createDataFrame
#     return self._create_dataframe(
#   File "/mnt2/yarn/usercache/livy/appcache/application_1729133052319_0026/container_1729133052319_0026_01_000001/pyspark.zip/pyspark/sql/session.py", line 1485, in _create_dataframe
#     rdd, struct = self._createFromLocal(map(prepare, data), schema)
#   File "/mnt2/yarn/usercache/livy/appcache/application_1729133052319_0026/container_1729133052319_0026_01_000001/pyspark.zip/pyspark/sql/session.py", line 1098, in _createFromLocal
#     struct.fields[i].name = name
# IndexError: list index out of range
