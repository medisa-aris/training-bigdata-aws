# %%
empData.show()
# Out:
# VBox()
# Starting Spark application
# <table>
# <tbody><tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>7</td><td>application_1729133052319_0008</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-10-2-64-24.ap-southeast-3.compute.internal:20888/proxy/application_1729133052319_0008/" class="emr-proxy-link j-9M5F2KY4568U application_1729133052319_0008" emr-resource="j-9M5F2KY4568U
# " application-id="application_1729133052319_0008">Link</a></td><td><a target="_blank" href="http://ip-10-2-64-30.ap-southeast-3.compute.internal:8042/node/containerlogs/container_1729133052319_0008_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></tbody></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# ...

# %%
wordsData = sc.textFile("hdfs:///user/hadoop/data-bay.csv")
wordsData.count()
