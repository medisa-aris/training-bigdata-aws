# %%
hdfs_path = "hdfs:///user/hadoop/employee_data.csv"
df = spark.read.csv(hdfs_path, header=True, inferSchema=True)
df.show(5)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---+---------+--------+---+-------+----------+----------+-----------+
# | id|firstname|lastname|age|dept_id| born_city| born_date|age_of_work|
# +---+---------+--------+---+-------+----------+----------+-----------+
# |  1|   QYbRxF|VhbPMuht| 36|     77|ygptEXwtrs|1995-02-27|         14|
# |  2|   SwGuje|kuQCDeRf| 20|     57|BUTrlMAtjU|1957-06-04|         -2|
# |  3|   MbhtKY|sjenQtVC| 22|     80|zQXDInOuri|1986-07-07|          2|
# |  4|   ZXEdyb|TNdmDYDI| 58|     46|VCKZgIgsll|1991-04-19|         38|
# |  5|   zZtNtN|qxrRbgPG| 20|     10|eBErCSgovD|1947-05-10|          0|
# +---+---------+--------+---+-------+----------+----------+-----------+
# only showing top 5 rows

# %%
df = spark.read.csv(HDPS, header=True, inferSchema=True)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# An error was encountered:
# java.net.UnknownHostException: user
# Traceback (most recent call last):
#   File "/mnt/yarn/usercache/livy/appcache/application_1729133052319_0014/container_1729133052319_0014_01_000001/pyspark.zip/pyspark/sql/readwriter.py", line 740, in csv
#     return self._df(self._jreader.csv(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#   File "/mnt/yarn/usercache/livy/appcache/application_1729133052319_0014/container_1729133052319_0014_01_000001/py4j-0.10.9.7-src.zip/py4j/java_gateway.py", line 1322, in __call__
#     return_value = get_return_value(
#   File "/mnt/yarn/usercache/livy/appcache/application_1729133052319_0014/container_1729133052319_0014_01_000001/pyspark.zip/pyspark/errors/exceptions/captured.py", line 185, in deco
#     raise converted from None
# ...
