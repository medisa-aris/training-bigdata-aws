# %%
from pyspark.sql import SparkSession

# Initialize Spark session
spark = SparkSession.builder \
    .appName("Yelp Reviews Loader") \
    .getOrCreate()
# Out:
# VBox()
# Starting Spark application
# <table>
# <tbody><tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>25</td><td>application_1729133052319_0030</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-10-2-64-24.ap-southeast-3.compute.internal:20888/proxy/application_1729133052319_0030/" class="emr-proxy-link j-9M5F2KY4568U application_1729133052319_0030" emr-resource="j-9M5F2KY4568U
# " application-id="application_1729133052319_0030">Link</a></td><td><a target="_blank" href="http://ip-10-2-64-22.ap-southeast-3.compute.internal:8042/node/containerlogs/container_1729133052319_0030_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></tbody></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Path to the JSON file on HDFS
hdfs_path = "/user/hadoop/yelp_academic_dataset_review.json"

# Load the JSON data into a PySpark DataFrame
df = spark.read.json(hdfs_path)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Show the schema to understand the structure of the DataFrame
df.printSchema()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- business_id: string (nullable = true)
#  |-- cool: long (nullable = true)
#  |-- date: string (nullable = true)
#  |-- funny: long (nullable = true)
#  |-- review_id: string (nullable = true)
#  |-- stars: double (nullable = true)
#  |-- text: string (nullable = true)
#  |-- useful: long (nullable = true)
#  |-- user_id: string (nullable = true)

# %%
# Show a sample of the data
df.show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |         business_id|cool|               date|funny|           review_id|stars|                text|useful|             user_id|
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |XQfwVwDr-v0ZS3_Cb...|   0|2018-07-07 22:09:11|    0|KU_O5udG6zpxOg-Vc...|  3.0|If you decide to ...|     0|mh_-eMZ6K5RLWhZyI...|
# |7ATYjTIgM3jUlt4UM...|   1|2012-01-03 15:28:18|    0|BiTunyQ73aT9WBnpR...|  5.0|I've taken a lot ...|     1|OyoGAe7OKpv6SyGZT...|
# |YjUWPpI6HXG530lwP...|   0|2014-02-05 20:30:30|    0|saUsX_uimxRlCVr67...|  3.0|Family diner. Had...|     0|8g_iMtfSiwikVnbP2...|
# |kxX2SOes4o-D3ZQBk...|   1|2015-01-04 00:01:03|    0|AqPFMleE6RsU23_au...|  5.0|Wow!  Yummy, diff...|     1|_7bHUi9Uuf5__HHc_...|
# |e4Vwtrqf-wpJfwesg...|   1|2017-01-14 20:54:15|    0|Sx8TMOWLNuJBWer-0...|  4.0|Cute interior and...|     1|bcjbaE6dDog4jkNY9...|
# |04UD14gamNjLY0IDY...|   1|2015-09-23 23:10:31|    2|JrIxlS1TzJ-iCu79u...|  1.0|I am a long term ...|     1|eUta8W_HdHMXPzLBB...|
# |gmjsEdUsKpj9Xxu6p...|   0|2015-01-03 23:21:18|    2|6AxgBCNX_PNTOxmbR...|  5.0|Loved this tour! ...|     0|r3zeYsv1XFBRA4dJp...|
# |LHSTtnW3YHCeUkRDG...|   0|2015-08-07 02:29:16|    0|_ZeMknuYdlQcUqng_...|  5.0|Amazingly amazing...|     2|yfFzsLmaWF2d4Sr0U...|
# |B5XSoSG3SfvQGtKEG...|   0|2016-03-30 22:46:33|    1|ZKvDG2sBvHVdF5oBN...|  3.0|This easter inste...|     1|wSTuiTk-sKNdcFypr...|
# |gebiRewfieSdtt17P...|   0|2016-07-25 07:31:06|    0|pUycOfUwM8vqX7KjR...|  3.0|Had a party of 6 ...|     0|59MxRhNVhU9MYndMk...|
# |uMvVYRgGNXf5boolA...|   0|2015-06-21 14:48:06|    0|rGQRf8UafX7OTlMNN...|  5.0|My experience wit...|     2|1WHRWwQmZOZDAhp2Q...|
# |EQ-TZ2eeD_E0BHuvo...|   0|2015-08-19 14:31:45|    0|l3Wk_mvAog6XANIuG...|  4.0|Locals recommende...|     0|ZbqSHbgCjzVAqaa7N...|
# |lj-E32x9_FA7GmUrB...|   0|2014-06-27 22:44:01|    0|XW_LfMv0fV21l9c6x...|  4.0|Love going here f...|     0|9OAtfnWag-ajVxRbU...|
# |RZtGWDLCAtuipwaZ-...|   0|2009-10-14 19:57:14|    0|8JFGBuHMoiNDyfcxu...|  4.0|Good food--loved ...|     0|smOvOajNG0lS4Pq7d...|
# |otQS34_MymijPTdNB...|   0|2011-10-27 17:12:05|    2|UBp0zWyH60Hmw6Fsa...|  4.0|The bun makes the...|     0|4Uh27DgGzsp6PqrH9...|
# |BVndHaLihEYbr76Z0...|   0|2014-10-11 16:22:06|    0|OAhBYw8IQ6wlfw1ow...|  5.0|Great place for b...|     0|1C2lxzUo1Hyye4RFI...|
# |YtSqYv1Q_pOltsVPS...|   0|2013-06-24 11:21:25|    0|oyaMhzBSwfGgemSGu...|  5.0|Tremendous servic...|     0|Dd1jQj7S-BFGqRbAp...|
# |rBdG_23USc7DletfZ...|   0|2014-08-10 19:41:43|    0|LnGZB0fjfgeVDVz5I...|  4.0|The hubby and I h...|     1|j2wlzrntrbKwyOcOi...|
# |CLEWowfkj-wKYJlQD...|   1|2016-03-07 00:02:18|    0|u2vzZaOqJ2feRshaa...|  5.0|I go to blow bar ...|     2|NDZvyYHTUWWu-kqgQ...|
# |eFvzHawVJofxSnD7T...|   0|2014-11-12 15:30:27|    0|Xs8Z8lmKkosqW5mw_...|  5.0|My absolute favor...|     0|IQsF3Rc6IgCzjVV9D...|
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# only showing top 20 rows

# %%
# Run a sample query to count the number of reviews per star rating
df.groupBy("stars").count().show()

# Run another sample query to filter reviews with at least 1 'useful' vote and display the top 10
df.filter(df.useful >= 1).select("review_id", "user_id", "business_id", "text", "useful").show(10, truncate=False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-----+-------+
# |stars|  count|
# +-----+-------+
# |  1.0|1069561|
# |  5.0|3231627|
# |  2.0| 544240|
# |  4.0|1452918|
# |  3.0| 691934|
# +-----+-------+
#
# +----------------------+----------------------+----------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |review_id             |user_id               |business_id           |text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |useful|
# +----------------------+----------------------+----------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# |BiTunyQ73aT9WBnpR9DZGw|OyoGAe7OKpv6SyGZT5g77Q|7ATYjTIgM3jUlt4UM3IypQ|I've taken a lot of spin classes over the years, and nothing compares to the classes at Body Cycle. From the nice, clean space and amazing bikes, to the welcoming and motivating instructors, every class is a top notch work out.\n\nFor anyone who struggles to fit workouts in, the online scheduling system makes it easy to plan ahead (and there's no need to line up way in advanced like many gyms make you do
                                                                                                                                                                                                                                                                                                                                                                                                                                      |1     |
# |u2vzZaOqJ2feRshaaF1doQ|NDZvyYHTUWWu-kqgQzzDGQ|CLEWowfkj-wKYJlQDqT1aw|I go to blow bar to get my brows done by natalie (brow specialist) which i highly recommend she is great does a great job on my eyebrows! But then i got a blow by victoria!! Wow i was impress i have thin, straight, dead hair and she left me with the biggest volume ive ever had!!! Tried another girl but didnt like it as much so victoria will be my girl for ever; very beautiful clean place!!!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |2     |
# |vBK79c3_1Ff_oqkh5VpfGg|Ohhrhu1RkqfVciIVx_W5HQ|nRKndeZLQ3eDL10UMwS2rQ|HOLY SMOKES!\n\nactual pumpkin pie mixed in with the frozen custard......are you kidding me? Why hasn't this become a huge sweep the nation treat. \n\nThe best part was the chunks of pie crust. Like finding a diamond inside another diamond. Super yummy.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |2     |
# +----------------------+----------------------+----------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# only showing top 10 rows

# %%
df1 = df
df1 = df1.withColumnRenamed("business_id", "business_id_1")
df1 = df1.withColumnRenamed("cool", "cool_1")
df1 = df1.withColumnRenamed("date", "date_1")
df1 = df1.withColumnRenamed("funny", "funny_1")
df1 = df1.withColumnRenamed("review_id", "review_id_1")
df1 = df1.withColumnRenamed("stars", "stars_1")
df1 = df1.withColumnRenamed("text", "text_1")
df1 = df1.withColumnRenamed("useful", "useful_1")

df2 = df
df2 = df2.withColumnRenamed("business_id", "business_id_2")
df2 = df2.withColumnRenamed("cool",               "cool_2")
df2 = df2.withColumnRenamed("date",               "date_2")
df2 = df2.withColumnRenamed("funny", "funny_2")
df2 = df2.withColumnRenamed("review_id", "review_id_2")
df2 = df2.withColumnRenamed("stars", "stars_2")
df2 = df2.withColumnRenamed("text", "text_2")
df2 = df2.withColumnRenamed("useful", "useful_2")

# Merge (join) the DataFrames on 'user_id'
# Using 'inner' join to merge only the matching rows between df1 and df2
merged_df = df1.join(df2, on="user_id", how="inner")

# df1 = merged_df

# df3 = df
# df3 = df3.withColumnRenamed("business_id", "business_id_3")
# df3 = df3.withColumnRenamed("cool",               "cool_3")
# df3 = df3.withColumnRenamed("date",               "date_3")
# df3 = df3.withColumnRenamed("funny", "funny_3")
# df3 = df3.withColumnRenamed("review_id", "review_id_3")
# df3 = df3.withColumnRenamed("stars", "stars_3")
# df3 = df3.withColumnRenamed("text", "text_3")
# df3 = df3.withColumnRenamed("useful", "useful_3")

# # Merge (join) the DataFrames on 'user_id'
# # Using 'inner' join to merge only the matching rows between df1 and df2
# merged_df = df1.join(df3, on="user_id", how="inner")

merged_df.count()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 163889603590

# %%
# Create a temporary view so that you can run SQL queries on it
merged_df.createOrReplaceTempView("yelp_reviews")

# Run an SQL query to count the number of reviews per star rating
query_1 = spark.sql("""
    SELECT stars_1, COUNT(*) AS review_count 
    FROM yelp_reviews 
    GROUP BY stars_1
    ORDER BY stars_1
""")

# Show the result of the first query
#query_1.show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#save to hadoop output
merged_df.write.mode("overwrite").json("/user/hadoop/output")
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Interrupted by user
