# %%
from pyspark.sql import SparkSession

# Initialize Spark session
spark = SparkSession.builder \
    .appName("Yelp Reviews Loader") \
    .getOrCreate()
# Out:
# VBox()
# Starting Spark application
# <table>
# <tbody><tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>30</td><td>application_1729133052319_0035</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-10-2-64-24.ap-southeast-3.compute.internal:20888/proxy/application_1729133052319_0035/" class="emr-proxy-link j-9M5F2KY4568U application_1729133052319_0035" emr-resource="j-9M5F2KY4568U
# " application-id="application_1729133052319_0035">Link</a></td><td><a target="_blank" href="http://ip-10-2-64-30.ap-southeast-3.compute.internal:8042/node/containerlogs/container_1729133052319_0035_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></tbody></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Path to the JSON file on HDFS
hdfs_path = "/user/hadoop/output"

# Load the JSON data into a PySpark DataFrame
df = spark.read.json(hdfs_path)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Show the schema to understand the structure of the DataFrame
df.printSchema()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- business_id_1: string (nullable = true)
#  |-- business_id_2: string (nullable = true)
#  |-- cool_1: long (nullable = true)
#  |-- cool_2: long (nullable = true)
#  |-- date_1: string (nullable = true)
#  |-- date_2: string (nullable = true)
#  |-- funny_1: long (nullable = true)
#  |-- funny_2: long (nullable = true)
#  |-- review_id_1: string (nullable = true)
#  |-- review_id_2: string (nullable = true)
#  |-- stars_1: double (nullable = true)
#  |-- stars_2: double (nullable = true)
#  |-- text_1: string (nullable = true)
#  |-- text_2: string (nullable = true)
#  |-- useful_1: long (nullable = true)
#  |-- useful_2: long (nullable = true)
#  |-- user_id: string (nullable = true)

# %%
# Show a sample of the data
df.count()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Create a temporary view so that you can run SQL queries on it
merged_df.createOrReplaceTempView("yelp_reviews")

# Run an SQL query to count the number of reviews per star rating
query_1 = spark.sql("""
    SELECT stars_1, COUNT(*) AS review_count 
    FROM yelp_reviews 
    GROUP BY stars_1
    ORDER BY stars_1
""")

# Show the result of the first query
#query_1.show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#save to hadoop output
merged_df.write.mode("overwrite").json("/user/hadoop/output")
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# An error was encountered:
# Invalid status code '400' from http://localhost:8998/sessions/26/statements/8 with error payload: {"msg":"requirement failed: Session isn't active."}
